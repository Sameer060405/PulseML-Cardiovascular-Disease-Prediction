# %% [markdown]
# # PulseML — Exploratory Data Analysis & Model Training
#
# This notebook walks through the full ML workflow:
# 1. Load dataset
# 2. Exploratory analysis
# 3. Train 5 classifiers
# 4. Compare metrics

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT))

import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from src.data_loader import load_dataset
from src.train import train_all
from src.config import METRICS_PATH

# %% [markdown]
# ## 1. Load data

# %%
df = load_dataset()
print(f"Rows: {len(df)}, Features: {len(df.columns)-1}")
df.head()

# %%
df.describe()

# %% [markdown]
# ## 2. Target balance & correlations

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
df["target"].value_counts().plot(kind="bar", ax=axes[0], color=["#4C78A8", "#F58518"])
axes[0].set_title("Class distribution")
sns.heatmap(df.corr(numeric_only=True), annot=True, fmt=".2f", cmap="RdBu_r", ax=axes[1])
axes[1].set_title("Correlation matrix")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Train all models

# %%
report = train_all()
pd.DataFrame(report["models"]).sort_values("roc_auc", ascending=False)

# %%
print("Best model:", report["best_model"])
print(json.dumps(report, indent=2))
